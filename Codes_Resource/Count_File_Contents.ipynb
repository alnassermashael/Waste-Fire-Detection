# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

a = "/content/drive/MyDrive/Data/train/images"
path, dirs, files = next(os.walk(a))
file_count = len(files)
print(file_count)
# Out:
# 5271
