# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
! unzip 'Folder/Path'

# %%
cp -r '/Folder/Source_Path' 'Folder/Destination_Path'

# %% [markdown]
# * Another way

# %%
import zipfile

with zipfile.ZipFile('Folder/Source_Path', 'r') as zf:
    # zf.printdir() # print zip contents
    zf.extractall('Folder/Destination_Path')
