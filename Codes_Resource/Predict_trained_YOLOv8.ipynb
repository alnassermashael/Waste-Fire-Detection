# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO(model = "yolov8n.pt")

# %%
! yolo    task=detect \
          mode=predict \
          model='/content/drive/MyDrive/training_results/train55/weights/best.pt' \
          conf=0.25 \
          source='/content/drive/MyDrive/fire_smoke_data/cat datasets/test/images'

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:5]:
        display(Image(filename=image_path, width=600))
        print('\n')
