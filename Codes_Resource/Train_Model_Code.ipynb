# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO(model = "yolov8n.pt")

# %%
#model.train(data = "/content/drive/MyDrive/train_model/data.yaml", epochs = 64, workers = 16, batch = 32, device = 0, nms = True)

! yolo     task=detect \
            mode=train \
            model=yolov8n.pt \
            data='{dataset.location}/data.yaml'\
            epochs=100\
            patience=15\
            optimizer='Adam'\
            nms=True\
            batch=36\
            device=0\
            name='Fire_Smoke_Detection_v8'

# %%
# !cp -r '/content/runs/detect/train' '/content/drive/MyDrive'
